# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_excel('/content/NO1Sep22-1Sep23.xlsx')
df1=df1.drop_duplicates()
df1
# Out:
#                       dt   values
# 0    2022-09-01 00:00:00  4312.00
# 1    2022-09-01 01:00:00  4356.00
# 2    2022-09-01 02:00:00     4.56
# 3    2022-09-01 03:00:00  4464.00
# 4    2022-09-01 04:00:00  4572.00
# ...                  ...      ...
# 8730 2023-08-31 19:00:00  2988.00
# 8731 2023-08-31 20:00:00  3568.00
# 8732 2023-08-31 21:00:00  4572.00
# 8733 2023-08-31 22:00:00     4.60
# 8734 2023-08-31 23:00:00  4580.00
#
# [8735 rows x 2 columns]

# %%
df2=pd.read_csv('/content/NO20_21.csv')
df2=df2.drop_duplicates()
df2
# Out:
#           Date;Value;Measurement
# 0     31-12-2020 01:00;2.984;KWH
# 1      31-12-2020 02:00;2.86;KWH
# 2         31-12-2020 03:00;4;KWH
# 3      31-12-2020 04:00;1.89;KWH
# 4     31-12-2020 05:00;3.552;KWH
# ...                          ...
# 8779  31-12-2021 20:00;1.914;KWH
# 8780  31-12-2021 21:00;3.018;KWH
# 8781  31-12-2021 22:00;1.946;KWH
# 8782  31-12-2021 23:00;3.434;KWH
# 8783  01-01-2022 00:00;2.114;KWH
#
# [8784 rows x 1 columns]

# %%
df2[['Date','Value','Measurement']]=df2['Date;Value;Measurement'].str.split(';',expand=True)
df2
# Out:
#           Date;Value;Measurement              Date  Value Measurement
# 0     31-12-2020 01:00;2.984;KWH  31-12-2020 01:00  2.984         KWH
# 1      31-12-2020 02:00;2.86;KWH  31-12-2020 02:00   2.86         KWH
# 2         31-12-2020 03:00;4;KWH  31-12-2020 03:00      4         KWH
# 3      31-12-2020 04:00;1.89;KWH  31-12-2020 04:00   1.89         KWH
# 4     31-12-2020 05:00;3.552;KWH  31-12-2020 05:00  3.552         KWH
# ...                          ...               ...    ...         ...
# 8779  31-12-2021 20:00;1.914;KWH  31-12-2021 20:00  1.914         KWH
# 8780  31-12-2021 21:00;3.018;KWH  31-12-2021 21:00  3.018         KWH
# 8781  31-12-2021 22:00;1.946;KWH  31-12-2021 22:00  1.946         KWH
# 8782  31-12-2021 23:00;3.434;KWH  31-12-2021 23:00  3.434         KWH
# 8783  01-01-2022 00:00;2.114;KWH  01-01-2022 00:00  2.114         KWH
#
# [8784 rows x 4 columns]

# %%
df2=df2.drop(columns='Date;Value;Measurement')
df2
# Out:
#                   Date  Value Measurement
# 0     31-12-2020 01:00  2.984         KWH
# 1     31-12-2020 02:00   2.86         KWH
# 2     31-12-2020 03:00      4         KWH
# 3     31-12-2020 04:00   1.89         KWH
# 4     31-12-2020 05:00  3.552         KWH
# ...                ...    ...         ...
# 8779  31-12-2021 20:00  1.914         KWH
# 8780  31-12-2021 21:00  3.018         KWH
# 8781  31-12-2021 22:00  1.946         KWH
# 8782  31-12-2021 23:00  3.434         KWH
# 8783  01-01-2022 00:00  2.114         KWH
#
# [8784 rows x 3 columns]

# %%
df2[['dates','time']]=df2['Date'].str.split(' ',expand=True)
df2
# Out:
#                   Date  Value Measurement       dates   time
# 0     31-12-2020 01:00  2.984         KWH  31-12-2020  01:00
# 1     31-12-2020 02:00   2.86         KWH  31-12-2020  02:00
# 2     31-12-2020 03:00      4         KWH  31-12-2020  03:00
# 3     31-12-2020 04:00   1.89         KWH  31-12-2020  04:00
# 4     31-12-2020 05:00  3.552         KWH  31-12-2020  05:00
# ...                ...    ...         ...         ...    ...
# 8779  31-12-2021 20:00  1.914         KWH  31-12-2021  20:00
# 8780  31-12-2021 21:00  3.018         KWH  31-12-2021  21:00
# 8781  31-12-2021 22:00  1.946         KWH  31-12-2021  22:00
# 8782  31-12-2021 23:00  3.434         KWH  31-12-2021  23:00
# 8783  01-01-2022 00:00  2.114         KWH  01-01-2022  00:00
#
# [8784 rows x 5 columns]

# %%
df2=df2.drop(columns='Date')

# %%
df2
df2['Measurement'].value_counts()
# Out:
# KWH    8784
# Name: Measurement, dtype: int64

# %%
df2=df2.drop(columns='Measurement')

# %%
df2
# Out:
#       Value       dates   time
# 0     2.984  31-12-2020  01:00
# 1      2.86  31-12-2020  02:00
# 2         4  31-12-2020  03:00
# 3      1.89  31-12-2020  04:00
# 4     3.552  31-12-2020  05:00
# ...     ...         ...    ...
# 8779  1.914  31-12-2021  20:00
# 8780  3.018  31-12-2021  21:00
# 8781  1.946  31-12-2021  22:00
# 8782  3.434  31-12-2021  23:00
# 8783  2.114  01-01-2022  00:00
#
# [8784 rows x 3 columns]

# %%
df2[['hour','minutes']]=df2['time'].str.split(':',expand=True)

# %%
df2
# Out:
#       Value       dates   time hour minutes
# 0     2.984  31-12-2020  01:00   01      00
# 1      2.86  31-12-2020  02:00   02      00
# 2         4  31-12-2020  03:00   03      00
# 3      1.89  31-12-2020  04:00   04      00
# 4     3.552  31-12-2020  05:00   05      00
# ...     ...         ...    ...  ...     ...
# 8779  1.914  31-12-2021  20:00   20      00
# 8780  3.018  31-12-2021  21:00   21      00
# 8781  1.946  31-12-2021  22:00   22      00
# 8782  3.434  31-12-2021  23:00   23      00
# 8783  2.114  01-01-2022  00:00   00      00
#
# [8784 rows x 5 columns]

# %%
df2['minutes'].value_counts()
# Out:
# 00    8784
# Name: minutes, dtype: int64

# %%
df2=df2.drop(columns='minutes')
df2.drop(columns='time')
# Out:
#       Value       dates hour
# 0     2.984  31-12-2020   01
# 1      2.86  31-12-2020   02
# 2         4  31-12-2020   03
# 3      1.89  31-12-2020   04
# 4     3.552  31-12-2020   05
# ...     ...         ...  ...
# 8779  1.914  31-12-2021   20
# 8780  3.018  31-12-2021   21
# 8781  1.946  31-12-2021   22
# 8782  3.434  31-12-2021   23
# 8783  2.114  01-01-2022   00
#
# [8784 rows x 3 columns]

# %%
df2
# Out:
#       Value       dates   time hour
# 0     2.984  31-12-2020  01:00   01
# 1      2.86  31-12-2020  02:00   02
# 2         4  31-12-2020  03:00   03
# 3      1.89  31-12-2020  04:00   04
# 4     3.552  31-12-2020  05:00   05
# ...     ...         ...    ...  ...
# 8779  1.914  31-12-2021  20:00   20
# 8780  3.018  31-12-2021  21:00   21
# 8781  1.946  31-12-2021  22:00   22
# 8782  3.434  31-12-2021  23:00   23
# 8783  2.114  01-01-2022  00:00   00
#
# [8784 rows x 4 columns]

# %%
df2[['DATE','MONTH','YEAR']]=df2['dates'].str.split('-',expand=True)

# %%
df2
# Out:
#       Value       dates   time hour DATE MONTH  YEAR
# 0     2.984  31-12-2020  01:00   01   31    12  2020
# 1      2.86  31-12-2020  02:00   02   31    12  2020
# 2         4  31-12-2020  03:00   03   31    12  2020
# 3      1.89  31-12-2020  04:00   04   31    12  2020
# 4     3.552  31-12-2020  05:00   05   31    12  2020
# ...     ...         ...    ...  ...  ...   ...   ...
# 8779  1.914  31-12-2021  20:00   20   31    12  2021
# 8780  3.018  31-12-2021  21:00   21   31    12  2021
# 8781  1.946  31-12-2021  22:00   22   31    12  2021
# 8782  3.434  31-12-2021  23:00   23   31    12  2021
# 8783  2.114  01-01-2022  00:00   00   01    01  2022
#
# [8784 rows x 7 columns]

# %%
df2=df2.drop(columns='dates')

# %%
df2=df2.drop(columns='time')

# %%
df1
# Out:
#                       dt   values
# 0    2022-09-01 00:00:00  4312.00
# 1    2022-09-01 01:00:00  4356.00
# 2    2022-09-01 02:00:00     4.56
# 3    2022-09-01 03:00:00  4464.00
# 4    2022-09-01 04:00:00  4572.00
# ...                  ...      ...
# 8730 2023-08-31 19:00:00  2988.00
# 8731 2023-08-31 20:00:00  3568.00
# 8732 2023-08-31 21:00:00  4572.00
# 8733 2023-08-31 22:00:00     4.60
# 8734 2023-08-31 23:00:00  4580.00
#
# [8735 rows x 2 columns]

# %%
df1['date']=df1['dt'].dt.day
df1['year']=df1['dt'].dt.year
df1['month']=df1['dt'].dt.month
df1['hour']=df1['dt'].dt.hour

# %%
df1
# Out:
#                       dt   values  date  year  month  hour
# 0    2022-09-01 00:00:00  4312.00     1  2022      9     0
# 1    2022-09-01 01:00:00  4356.00     1  2022      9     1
# 2    2022-09-01 02:00:00     4.56     1  2022      9     2
# 3    2022-09-01 03:00:00  4464.00     1  2022      9     3
# 4    2022-09-01 04:00:00  4572.00     1  2022      9     4
# ...                  ...      ...   ...   ...    ...   ...
# 8730 2023-08-31 19:00:00  2988.00    31  2023      8    19
# 8731 2023-08-31 20:00:00  3568.00    31  2023      8    20
# 8732 2023-08-31 21:00:00  4572.00    31  2023      8    21
# 8733 2023-08-31 22:00:00     4.60    31  2023      8    22
# 8734 2023-08-31 23:00:00  4580.00    31  2023      8    23
#
# [8735 rows x 6 columns]

# %%
df1=df1.drop(columns='dt')

# %%
df1
# Out:
#        values  date  year  month  hour
# 0     4312.00     1  2022      9     0
# 1     4356.00     1  2022      9     1
# 2        4.56     1  2022      9     2
# 3     4464.00     1  2022      9     3
# 4     4572.00     1  2022      9     4
# ...       ...   ...   ...    ...   ...
# 8730  2988.00    31  2023      8    19
# 8731  3568.00    31  2023      8    20
# 8732  4572.00    31  2023      8    21
# 8733     4.60    31  2023      8    22
# 8734  4580.00    31  2023      8    23
#
# [8735 rows x 5 columns]

# %%
df1['year'].value_counts()
# Out:
# 2023    5831
# 2022    2904
# Name: year, dtype: int64

# %%
df2
# Out:
#       Value hour DATE MONTH  YEAR
# 0     2.984   01   31    12  2020
# 1      2.86   02   31    12  2020
# 2         4   03   31    12  2020
# 3      1.89   04   31    12  2020
# 4     3.552   05   31    12  2020
# ...     ...  ...  ...   ...   ...
# 8779  1.914   20   31    12  2021
# 8780  3.018   21   31    12  2021
# 8781  1.946   22   31    12  2021
# 8782  3.434   23   31    12  2021
# 8783  2.114   00   01    01  2022
#
# [8784 rows x 5 columns]

# %%
df2=df2.rename(columns={'DATE' : 'date'})

# %%
df2=df2.rename(columns={'MONTH':'month'})
df2=df2.rename(columns={'YEAR':'year'})
df2=df2.rename(columns={'Value' : 'values'})
df1['values']=df1['values']/1000

# %%
df2
# Out:
#      values hour date month  year
# 0     2.984   01   31    12  2020
# 1      2.86   02   31    12  2020
# 2         4   03   31    12  2020
# 3      1.89   04   31    12  2020
# 4     3.552   05   31    12  2020
# ...     ...  ...  ...   ...   ...
# 8779  1.914   20   31    12  2021
# 8780  3.018   21   31    12  2021
# 8781  1.946   22   31    12  2021
# 8782  3.434   23   31    12  2021
# 8783  2.114   00   01    01  2022
#
# [8784 rows x 5 columns]

# %%
df1
# Out:
#        values  date  year  month  hour
# 0     4.31200     1  2022      9     0
# 1     4.35600     1  2022      9     1
# 2     0.00456     1  2022      9     2
# 3     4.46400     1  2022      9     3
# 4     4.57200     1  2022      9     4
# ...       ...   ...   ...    ...   ...
# 8730  2.98800    31  2023      8    19
# 8731  3.56800    31  2023      8    20
# 8732  4.57200    31  2023      8    21
# 8733  0.00460    31  2023      8    22
# 8734  4.58000    31  2023      8    23
#
# [8735 rows x 5 columns]

# %%
df1['year'].value_counts()
# Out:
# 2023    5831
# 2022    2904
# Name: year, dtype: int64

# %%
df2['year'].value_counts()
# Out:
# 2021    8760
# 2020      23
# 2022       1
# Name: year, dtype: int64

# %%
df2.drop(df2.head(23).index,inplace=True)
df2.drop(df2.tail(1).index,inplace=True)
df2=df2.reset_index()

# %%
df2
# Out:
#       index values hour date month  year
# 0        23  3.684   00   01    01  2021
# 1        24  2.578   01   01    01  2021
# 2        25  3.748   02   01    01  2021
# 3        26  1.954   03   01    01  2021
# 4        27  3.262   04   01    01  2021
# ...     ...    ...  ...  ...   ...   ...
# 8755   8778  7.886   19   31    12  2021
# 8756   8779  1.914   20   31    12  2021
# 8757   8780  3.018   21   31    12  2021
# 8758   8781  1.946   22   31    12  2021
# 8759   8782  3.434   23   31    12  2021
#
# [8760 rows x 6 columns]

# %%
df2['year'].value_counts()
# Out:
# 2021    8760
# Name: year, dtype: int64

# %%
df2=df2.drop(columns='index')
df2
# Out:
#      values hour date month  year
# 0     3.684   00   01    01  2021
# 1     2.578   01   01    01  2021
# 2     3.748   02   01    01  2021
# 3     1.954   03   01    01  2021
# 4     3.262   04   01    01  2021
# ...     ...  ...  ...   ...   ...
# 8755  7.886   19   31    12  2021
# 8756  1.914   20   31    12  2021
# 8757  3.018   21   31    12  2021
# 8758  1.946   22   31    12  2021
# 8759  3.434   23   31    12  2021
#
# [8760 rows x 5 columns]

# %%
df1
# Out:
#        values  date  year  month  hour
# 0     4.31200     1  2022      9     0
# 1     4.35600     1  2022      9     1
# 2     0.00456     1  2022      9     2
# 3     4.46400     1  2022      9     3
# 4     4.57200     1  2022      9     4
# ...       ...   ...   ...    ...   ...
# 8730  2.98800    31  2023      8    19
# 8731  3.56800    31  2023      8    20
# 8732  4.57200    31  2023      8    21
# 8733  0.00460    31  2023      8    22
# 8734  4.58000    31  2023      8    23
#
# [8735 rows x 5 columns]

# %%
df1=df1.sort_values(by=['month','date','hour'])

# %%
df1
# Out:
#       values  date  year  month  hour
# 2904   4.428     1  2023      1     0
# 2905   4.220     1  2023      1     1
# 2906   4.084     1  2023      1     2
# 2907   6.180     1  2023      1     3
# 2908   4.300     1  2023      1     4
# ...      ...   ...   ...    ...   ...
# 2899  10.180    31  2022     12    19
# 2900   4.484    31  2022     12    20
# 2901   4.356    31  2022     12    21
# 2902   4.384    31  2022     12    22
# 2903   6.260    31  2022     12    23
#
# [8735 rows x 5 columns]

# %%
df1_2023=df1[:(8735-2904)]
df1_2022=df1[(8735-2904):]

# %%
df1_2023
df1_2022
# Out:
#         values  date  year  month  hour
# 0      4.31200     1  2022      9     0
# 1      4.35600     1  2022      9     1
# 2      0.00456     1  2022      9     2
# 3      4.46400     1  2022      9     3
# 4      4.57200     1  2022      9     4
# ...        ...   ...   ...    ...   ...
# 2899  10.18000    31  2022     12    19
# 2900   4.48400    31  2022     12    20
# 2901   4.35600    31  2022     12    21
# 2902   4.38400    31  2022     12    22
# 2903   6.26000    31  2022     12    23
#
# [2904 rows x 5 columns]

# %%
df1_2023
# Out:
#       values  date  year  month  hour
# 2904  4.4280     1  2023      1     0
# 2905  4.2200     1  2023      1     1
# 2906  4.0840     1  2023      1     2
# 2907  6.1800     1  2023      1     3
# 2908  4.3000     1  2023      1     4
# ...      ...   ...   ...    ...   ...
# 8730  2.9880    31  2023      8    19
# 8731  3.5680    31  2023      8    20
# 8732  4.5720    31  2023      8    21
# 8733  0.0046    31  2023      8    22
# 8734  4.5800    31  2023      8    23
#
# [5831 rows x 5 columns]

# %%
df2
# Out:
#      values hour date month  year
# 0     3.684   00   01    01  2021
# 1     2.578   01   01    01  2021
# 2     3.748   02   01    01  2021
# 3     1.954   03   01    01  2021
# 4     3.262   04   01    01  2021
# ...     ...  ...  ...   ...   ...
# 8755  7.886   19   31    12  2021
# 8756  1.914   20   31    12  2021
# 8757  3.018   21   31    12  2021
# 8758  1.946   22   31    12  2021
# 8759  3.434   23   31    12  2021
#
# [8760 rows x 5 columns]

# %%
df1_2023=df1_2023.reset_index(drop=True)

# %%
df1_2023
# Out:
#       values  date  year  month  hour
# 0     4.4280     1  2023      1     0
# 1     4.2200     1  2023      1     1
# 2     4.0840     1  2023      1     2
# 3     6.1800     1  2023      1     3
# 4     4.3000     1  2023      1     4
# ...      ...   ...   ...    ...   ...
# 5826  2.9880    31  2023      8    19
# 5827  3.5680    31  2023      8    20
# 5828  4.5720    31  2023      8    21
# 5829  0.0046    31  2023      8    22
# 5830  4.5800    31  2023      8    23
#
# [5831 rows x 5 columns]

# %%
df1_2023
# Out:
#       values  date  year  month  hour
# 0     4.4280     1  2023      1     0
# 1     4.2200     1  2023      1     1
# 2     4.0840     1  2023      1     2
# 3     6.1800     1  2023      1     3
# 4     4.3000     1  2023      1     4
# ...      ...   ...   ...    ...   ...
# 5826  2.9880    31  2023      8    19
# 5827  3.5680    31  2023      8    20
# 5828  4.5720    31  2023      8    21
# 5829  0.0046    31  2023      8    22
# 5830  4.5800    31  2023      8    23
#
# [5831 rows x 5 columns]

# %%
df2['year'] = df2['year'].astype(int)
df2['month'] = df2['month'].astype(int)
df2['date'] = df2['date'].astype(int)
df2['hour'] = df2['hour'].astype(int)

for i in range(5830):
    new_row_data = {
        'date': df1_2023.iloc[i]['date'],
        'year': 2022,
        'month': df1_2023.iloc[i]['month'],
        'hour': df1_2023.iloc[i]['hour'],
        'values': (float(df1_2023.iloc[i]['values']) + float(df2.iloc[i]['values'])) / 2
    }
    df1_2022.loc[2904 + i] = new_row_data.copy()

# %%
df1_2022
# Out:
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      3.399   1.0  2022    1.0   1.0
# 2      3.916   1.0  2022    1.0   2.0
# 3      4.067   1.0  2022    1.0   3.0
# 4      3.781   1.0  2022    1.0   4.0
# ...      ...   ...   ...    ...   ...
# 8753  10.180  31.0  2022   12.0  19.0
# 8754   4.484  31.0  2022   12.0  20.0
# 8755   4.356  31.0  2022   12.0  21.0
# 8756   4.384  31.0  2022   12.0  22.0
# 8757   6.260  31.0  2022   12.0  23.0
#
# [8758 rows x 5 columns]

# %%
df1_2022['month'].value_counts()
# Out:
# 1.0     1488
# 3.0     1486
# 4.0     1440
# 2.0     1344
# 5.0      769
# 7.0      744
# 8.0      743
# 6.0      720
# 12.0      24
# Name: month, dtype: int64

# %%
df1_2022['month'].value_counts()
# Out:
# 1.0     1488
# 3.0     1486
# 4.0     1440
# 2.0     1344
# 5.0      769
# 7.0      744
# 8.0      743
# 6.0      720
# 12.0      24
# Name: month, dtype: int64

# %%
value_counts_by_month_date = df1_2022.groupby(['month', 'date']).size()

# %%
value_counts_by_month_date_df = value_counts_by_month_date.reset_index(name='counts')

# %%
value_counts_by_month_date_df
# Out:
#      month  date  counts
# 0      1.0   1.0      48
# 1      1.0   2.0      48
# 2      1.0   3.0      48
# 3      1.0   4.0      48
# 4      1.0   5.0      48
# ..     ...   ...     ...
# 239    8.0  28.0      24
# 240    8.0  29.0      24
# 241    8.0  30.0      24
# 242    8.0  31.0      23
# 243   12.0  31.0      24
#
# [244 rows x 3 columns]

# %%
value_counts_by_month_date_df['counts'].value_counts()
# Out:
# 24    121
# 48    120
# 46      1
# 25      1
# 23      1
# Name: counts, dtype: int64

# %%
# 30 OCTOBER DATA IS MISSING
df1_2022=df1_2022.sort_values(by=['month','date','hour'])
october_31_data = df1_2022[(df1_2022['month'] == 10) & (df1_2022['date'] == 31)]

# Replace the date and month with October 30th
october_31_data['date'] = 30
october_31_data['month'] = 10

# Append the modified data back to the DataFrame
df1_2022 = df1_2022.append(october_31_data, ignore_index=True)
# Out:
# <ipython-input-532-22918d268ac7>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1_2022 = df1_2022.append(october_31_data, ignore_index=True)

# %%
df1_2022.sort_values(by=['month','date','hour'],inplace=True)
df1_2022=df1_2022.reset_index(drop=True)

# %%
df1_2022
# Out:
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      4.056   1.0  2022    1.0   0.0
# 2      3.399   1.0  2022    1.0   1.0
# 3      3.399   1.0  2022    1.0   1.0
# 4      3.916   1.0  2022    1.0   2.0
# ...      ...   ...   ...    ...   ...
# 8753  10.180  31.0  2022   12.0  19.0
# 8754   4.484  31.0  2022   12.0  20.0
# 8755   4.356  31.0  2022   12.0  21.0
# 8756   4.384  31.0  2022   12.0  22.0
# 8757   6.260  31.0  2022   12.0  23.0
#
# [8758 rows x 5 columns]

# %%
df1_2022=df1_2022.reset_index(drop=True)
df1_2022
# Out:
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      4.056   1.0  2022    1.0   0.0
# 2      3.399   1.0  2022    1.0   1.0
# 3      3.399   1.0  2022    1.0   1.0
# 4      3.916   1.0  2022    1.0   2.0
# ...      ...   ...   ...    ...   ...
# 8753  10.180  31.0  2022   12.0  19.0
# 8754   4.484  31.0  2022   12.0  20.0
# 8755   4.356  31.0  2022   12.0  21.0
# 8756   4.384  31.0  2022   12.0  22.0
# 8757   6.260  31.0  2022   12.0  23.0
#
# [8758 rows x 5 columns]

# %%
for i in range (5830,8758):
  new_row_data={'date': df1_2022.iloc[i]['date'],'year': 2023,'month': df1_2022.iloc[i]['month'], 'hour':df1_2022.iloc[i]['hour'], 'values': (float(2*(df1_2022.iloc[i]['values']))-float(df2.iloc[i]['values']))}
  df1_2023.loc[i] = new_row_data

# %%
df1_2023
# Out:
#       values  date  year  month  hour
# 0      4.428   1.0  2023    1.0   0.0
# 1      4.220   1.0  2023    1.0   1.0
# 2      4.084   1.0  2023    1.0   2.0
# 3      6.180   1.0  2023    1.0   3.0
# 4      4.300   1.0  2023    1.0   4.0
# ...      ...   ...   ...    ...   ...
# 8753  11.102  31.0  2023   12.0  19.0
# 8754  -0.650  31.0  2023   12.0  20.0
# 8755   0.826  31.0  2023   12.0  21.0
# 8756   6.854  31.0  2023   12.0  22.0
# 8757   9.502  31.0  2023   12.0  23.0
#
# [8758 rows x 5 columns]

# %%
df_2023=df1_2023
df_2022=df1_2022
df_2021=df2

# %%
df_2023
# Out:
#       values  date  year  month  hour
# 0      4.428   1.0  2023    1.0   0.0
# 1      4.220   1.0  2023    1.0   1.0
# 2      4.084   1.0  2023    1.0   2.0
# 3      6.180   1.0  2023    1.0   3.0
# 4      4.300   1.0  2023    1.0   4.0
# ...      ...   ...   ...    ...   ...
# 8753  11.102  31.0  2023   12.0  19.0
# 8754  -0.650  31.0  2023   12.0  20.0
# 8755   0.826  31.0  2023   12.0  21.0
# 8756   6.854  31.0  2023   12.0  22.0
# 8757   9.502  31.0  2023   12.0  23.0
#
# [8758 rows x 5 columns]

# %%
# Filter data for August 30th
august_30_data = df_2022[(df_2022['month'] == 8) & (df_2022['date'] == 30) & (df_2022['hour']==23)]

# Replace the date with August 31st
august_30_data['date'] = 31

# Append the modified data back to the DataFrame
df_2022 = df_2022.append(august_30_data, ignore_index=True)
df_2022.sort_values(by=['month','date','hour'], inplace=True)
march_26_data=df_2022[(df_2022['month']==3) & (df_2022['date']==25) & (df_2022['hour']==23)]
march_26_data['date'] = 26
df_2022 = df_2022.append(march_26_data, ignore_index=True)
df_2022.sort_values(by=['month','date','hour'], inplace=True)
df_2022
# Out:
# <ipython-input-540-b6e7d22c763f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   august_30_data['date'] = 31
# <ipython-input-540-b6e7d22c763f>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_2022 = df_2022.append(august_30_data, ignore_index=True)
# <ipython-input-540-b6e7d22c763f>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   march_26_data['date'] = 26
# <ipython-input-540-b6e7d22c763f>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_2022 = df_2022.append(march_26_data, ignore_index=True)
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      4.056   1.0  2022    1.0   0.0
# 2      3.399   1.0  2022    1.0   1.0
# 3      3.399   1.0  2022    1.0   1.0
# 4      3.916   1.0  2022    1.0   2.0
# ...      ...   ...   ...    ...   ...
# 8754  10.180  31.0  2022   12.0  19.0
# 8755   4.484  31.0  2022   12.0  20.0
# 8756   4.356  31.0  2022   12.0  21.0
# 8757   4.384  31.0  2022   12.0  22.0
# 8758   6.260  31.0  2022   12.0  23.0
#
# [8761 rows x 5 columns]

# %%
df_2022
# Out:
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      4.056   1.0  2022    1.0   0.0
# 2      3.399   1.0  2022    1.0   1.0
# 3      3.399   1.0  2022    1.0   1.0
# 4      3.916   1.0  2022    1.0   2.0
# ...      ...   ...   ...    ...   ...
# 8754  10.180  31.0  2022   12.0  19.0
# 8755   4.484  31.0  2022   12.0  20.0
# 8756   4.356  31.0  2022   12.0  21.0
# 8757   4.384  31.0  2022   12.0  22.0
# 8758   6.260  31.0  2022   12.0  23.0
#
# [8761 rows x 5 columns]

# %%
df_2022['month'].value_counts()
# Out:
# 1.0     1488
# 3.0     1488
# 4.0     1440
# 2.0     1344
# 5.0      769
# 7.0      744
# 8.0      744
# 6.0      720
# 12.0      24
# Name: month, dtype: int64

# %%
df_2022['date'].value_counts()
df_2022=df_2022.reset_index(drop=True)

# %%
value_counts_by_month_date = df1_2022.groupby(['month', 'date']).size()
value_counts_by_month_date_df=value_counts_by_month_date.reset_index()

value_counts_by_month_date_df
# Out:
#      month  date   0
# 0      1.0   1.0  48
# 1      1.0   2.0  48
# 2      1.0   3.0  48
# 3      1.0   4.0  48
# 4      1.0   5.0  48
# ..     ...   ...  ..
# 239    8.0  28.0  24
# 240    8.0  29.0  24
# 241    8.0  30.0  24
# 242    8.0  31.0  23
# 243   12.0  31.0  24
#
# [244 rows x 3 columns]

# %%
df_2021
# Out:
#      values  hour  date  month  year
# 0     3.684     0     1      1  2021
# 1     2.578     1     1      1  2021
# 2     3.748     2     1      1  2021
# 3     1.954     3     1      1  2021
# 4     3.262     4     1      1  2021
# ...     ...   ...   ...    ...   ...
# 8755  7.886    19    31     12  2021
# 8756  1.914    20    31     12  2021
# 8757  3.018    21    31     12  2021
# 8758  1.946    22    31     12  2021
# 8759  3.434    23    31     12  2021
#
# [8760 rows x 5 columns]

# %%
df_2022
# Out:
#       values  date  year  month  hour
# 0      4.056   1.0  2022    1.0   0.0
# 1      4.056   1.0  2022    1.0   0.0
# 2      3.399   1.0  2022    1.0   1.0
# 3      3.399   1.0  2022    1.0   1.0
# 4      3.916   1.0  2022    1.0   2.0
# ...      ...   ...   ...    ...   ...
# 8756  10.180  31.0  2022   12.0  19.0
# 8757   4.484  31.0  2022   12.0  20.0
# 8758   4.356  31.0  2022   12.0  21.0
# 8759   4.384  31.0  2022   12.0  22.0
# 8760   6.260  31.0  2022   12.0  23.0
#
# [8761 rows x 5 columns]

# %%
df_2020 = pd.DataFrame()
for i in range(0, 8760):
    new_row = {'date': df_2021.loc[i]['date'],
           'year': 2020,
           'month': df_2021.loc[i]['month'],
           'hour': df_2021.loc[i]['hour'],
           'values': ((2 * float(df_2021.loc[i]['values'])) - (float(df_2022.loc[i]['values'])))}

    df_2020 = pd.concat([df_2020, pd.DataFrame([new_row])], ignore_index=True)
df_2020
# Out:
#       date  year  month  hour  values
# 0        1  2020      1     0   3.312
# 1        1  2020      1     1   1.100
# 2        1  2020      1     2   4.097
# 3        1  2020      1     3   0.509
# 4        1  2020      1     4   2.608
# ...    ...   ...    ...   ...     ...
# 8755    31  2020     12    19  -0.824
# 8756    31  2020     12    20  -6.352
# 8757    31  2020     12    21   1.552
# 8758    31  2020     12    22  -0.464
# 8759    31  2020     12    23   2.484
#
# [8760 rows x 5 columns]

# %%
# Create empty DataFrames for years 2019 and 2018
df_2019 = pd.DataFrame()
df_2018 = pd.DataFrame()

# Loop through the range of indices
for i in range(0, 8760):
    # Calculate values for the respective years
    values_2019 = ((2 * float(df_2020.loc[i]['values'])) - (float(df_2021.loc[i]['values'])))
    values_2018 = ((3 * float(df_2020.loc[i]['values'])) - (float(df_2021.loc[i]['values'])))  # Assuming df_2023 exists for 2018 data

    # Create new rows for each year and append them to the respective DataFrames
    new_row_2019 = {'date': df_2021.loc[i]['date'],
                    'year': 2019,
                    'month': df_2021.loc[i]['month'],
                    'hour': df_2021.loc[i]['hour'],
                    'values': values_2019}
    new_row_2018 = {'date': df_2021.loc[i]['date'],
                    'year': 2018,
                    'month': df_2021.loc[i]['month'],
                    'hour': df_2021.loc[i]['hour'],
                    'values': values_2018}

    df_2019 = pd.concat([df_2019, pd.DataFrame([new_row_2019])], ignore_index=True)
    df_2018 = pd.concat([df_2018, pd.DataFrame([new_row_2018])], ignore_index=True)

# Output the DataFrames for the respective years
print("DataFrame for 2020:")
print(df_2020)
print("\nDataFrame for 2019:")
print(df_2019)
print("\nDataFrame for 2018:")
print(df_2018)
# Out:
# DataFrame for 2020:
#       date  year  month  hour  values
# 0        1  2020      1     0   3.312
# 1        1  2020      1     1   1.100
# 2        1  2020      1     2   4.097
# 3        1  2020      1     3   0.509
# 4        1  2020      1     4   2.608
# ...    ...   ...    ...   ...     ...
# 8755    31  2020     12    19  -0.824
# 8756    31  2020     12    20  -6.352
# 8757    31  2020     12    21   1.552
# 8758    31  2020     12    22  -0.464
# 8759    31  2020     12    23   2.484
#
# [8760 rows x 5 columns]
#
# DataFrame for 2019:
#       date  year  month  hour  values
# 0        1  2019      1     0   2.940
# 1        1  2019      1     1  -0.378
# 2        1  2019      1     2   4.446
# 3        1  2019      1     3  -0.936
# 4        1  2019      1     4   1.954
# ...    ...   ...    ...   ...     ...
# 8755    31  2019     12    19  -9.534
# 8756    31  2019     12    20 -14.618
# 8757    31  2019     12    21   0.086
# 8758    31  2019     12    22  -2.874
# 8759    31  2019     12    23   1.534
#
# [8760 rows x 5 columns]
#
# DataFrame for 2018:
#       date  year  month  hour  values
# 0        1  2018      1     0   6.252
# 1        1  2018      1     1   0.722
# 2        1  2018      1     2   8.543
# 3        1  2018      1     3  -0.427
# 4        1  2018      1     4   4.562
# ...    ...   ...    ...   ...     ...
# 8755    31  2018     12    19 -10.358
# 8756    31  2018     12    20 -20.970
# 8757    31  2018     12    21   1.638
# 8758    31  2018     12    22  -3.338
# 8759    31  2018     12    23   4.018
#
# [8760 rows x 5 columns]
