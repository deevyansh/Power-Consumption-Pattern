# %%
#Importing the datas
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv('VA_file2.csv')
df=pd.read_csv('VA_file1.csv')
df['year']=df['year'].astype(int)
df['month']=df['month'].astype(int)
df1['year']=df1['year'].astype(int)
df1['month']=df1['month'].astype(int)
df1['date']=df1['date'].astype(int)
df = pd.concat([df1, df])
df=df.drop(columns=['Unnamed: 0', 'index'])

# %%
df
# Out:
#       values  date  month  year  hour
# 0        5.6     1      1  2021   0.0
# 1        5.6     1      1  2021   1.0
# 2        5.6     1      1  2021   2.0
# 3        5.2     1      1  2021   3.0
# 4        6.0     1      1  2021   4.0
# ...      ...   ...    ...   ...   ...
# 8731     6.4    31     12  2022  19.0
# 8732     4.4    31     12  2022  20.0
# 8733     4.8    31     12  2022  21.0
# 8734     4.4    31     12  2022  22.0
# 8735     6.2    31     12  2022  23.0
#
# [17496 rows x 5 columns]

# %%
#PER DAY ANALYSIS
Hourly_average_consumption = df.groupby(['year', 'month', 'date'])['values'].mean()
Hourly_average_consumption_df = Hourly_average_consumption.reset_index()
Hourly_average_consumption_df = Hourly_average_consumption_df.rename(columns={'values': 'Hourly_average_consumption'})
Hourly_average_consumption_df
# Out:
#      year  month  date  Hourly_average_consumption
# 0    2021      1     1                    6.616667
# 1    2021      1     2                    6.966667
# 2    2021      1     3                    7.750000
# 3    2021      1     4                  120.083333
# 4    2021      1     5                  309.383333
# ..    ...    ...   ...                         ...
# 724  2023      8    27                    5.825000
# 725  2023      8    28                    9.733333
# 726  2023      8    29                  103.900000
# 727  2023      8    30                  150.750000
# 728  2023      8    31                  154.558333
#
# [729 rows x 4 columns]

# %%
Hourly_maximum_consumption= df.groupby(['year','month','date'])['values'].max()
Hourly_maximum_consumption_df=Hourly_maximum_consumption.reset_index()
Hourly_maximum_consumption_df=Hourly_maximum_consumption_df.rename(columns={'values' :'Hourly_maximum_consumption' })
Hourly_maximum_consumption_df
# Out:
#      year  month  date  Hourly_maximum_consumption
# 0    2021      1     1                         9.6
# 1    2021      1     2                        10.8
# 2    2021      1     3                        10.4
# 3    2021      1     4                       324.8
# 4    2021      1     5                       339.6
# ..    ...    ...   ...                         ...
# 724  2023      8    27                         6.6
# 725  2023      8    28                        16.2
# 726  2023      8    29                       203.6
# 727  2023      8    30                       188.2
# 728  2023      8    31                       176.2
#
# [729 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from datetime import date
for i in range (0,729):
  Hourly_average_consumption_df.loc[i,'day']=date(Hourly_average_consumption_df.loc[i,'year'],Hourly_average_consumption_df.loc[i,'month'], Hourly_average_consumption_df.loc[i,'date'])

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(Hourly_average_consumption_df['day'],Hourly_average_consumption_df['Hourly_average_consumption'])
ax.set_xlabel('date')
ax.set_title('Graph of Hourly Average Consumption')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import date
for i in range (0,729):
  Hourly_maximum_consumption_df.loc[i,'day']=date(Hourly_maximum_consumption_df.loc[i,'year'],Hourly_maximum_consumption_df.loc[i,'month'], Hourly_maximum_consumption_df.loc[i,'date'])

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(Hourly_maximum_consumption_df['day'],Hourly_maximum_consumption_df['Hourly_maximum_consumption'])
ax.set_xlabel('date')
ax.set_title('Graph of Hourly Maximum Consumption')
plt.grid(True)
plt.show()

# %%
daily_sum= df.groupby(['year','month','date'])['values'].sum()
daily_sum_df=daily_sum.reset_index()
daily_sum_df=daily_sum_df.rename(columns={'values' :'total of the day' })
daily_sum_df
# Out:
#      year  month  date  total of the day
# 0    2021      1     1             158.8
# 1    2021      1     2             167.2
# 2    2021      1     3             186.0
# 3    2021      1     4            2882.0
# 4    2021      1     5            7425.2
# ..    ...    ...   ...               ...
# 724  2023      8    27             139.8
# 725  2023      8    28             233.6
# 726  2023      8    29            2493.6
# 727  2023      8    30            3618.0
# 728  2023      8    31            3709.4
#
# [729 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from datetime import date
for i in range (0,729):
  daily_sum_df.loc[i,'day']=date(daily_sum_df.loc[i,'year'],daily_sum_df.loc[i,'month'], daily_sum_df.loc[i,'date'])

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(daily_sum_df['day'],daily_sum_df['total of the day'])
ax.set_xlabel('date')
ax.set_title('Daily_Sum')
plt.grid(True)
plt.show()

# %%
#PER MONTH ANALYSIS
Daily_average_consumption = daily_sum_df.groupby(['year', 'month'])['total of the day'].mean()
Daily_average_consumption_df=Daily_average_consumption.reset_index()
Daily_average_consumption_df=Daily_average_consumption_df.rename(columns={'total of the day':'Daily_average_consumption'})
Daily_average_consumption_df
# Out:
#     year  month  Daily_average_consumption
# 0   2021      1                5655.535484
# 1   2021      2                4228.542857
# 2   2021      3                5942.851613
# 3   2021      4                2725.320000
# 4   2021      5                3468.890323
# 5   2021      6                3483.640000
# 6   2021      7                2831.767742
# 7   2021      8                2104.116129
# 8   2021      9                2980.013333
# 9   2021     10                3985.393548
# 10  2021     11                5077.720000
# 11  2021     12                3284.903226
# 12  2022      9                2235.133333
# 13  2022     10                1901.133333
# 14  2022     11                2580.340000
# 15  2022     12                2060.987097
# 16  2023      1                1824.187097
# 17  2023      2                2080.007143
# 18  2023      3                1697.748387
# 19  2023      4                1167.726667
# 20  2023      5                1314.774194
# ...

# %%
import matplotlib.pyplot as plt
from datetime import date
for i in range (0,24):
  Daily_average_consumption_df.loc[i,'day']=date(Daily_average_consumption_df.loc[i,'year'],Daily_average_consumption_df.loc[i,'month'],1)

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(Daily_average_consumption_df['day'],Daily_average_consumption_df['Daily_average_consumption'])
ax.set_xlabel('date')
ax.set_title('Daily_average_consumption')
plt.grid(True)
plt.show()

# %%
monthly_total = daily_sum_df.groupby(['year', 'month'])['total of the day'].sum()
monthly_total_df=monthly_total.reset_index()
monthly_total_df=monthly_total_df.rename(columns={'total of the day':'monthly_total'})
monthly_total_df
# Out:
#     year  month  monthly_total
# 0   2021      1       175321.6
# 1   2021      2       118399.2
# 2   2021      3       184228.4
# 3   2021      4        81759.6
# 4   2021      5       107535.6
# 5   2021      6       104509.2
# 6   2021      7        87784.8
# 7   2021      8        65227.6
# 8   2021      9        89400.4
# 9   2021     10       123547.2
# 10  2021     11       152331.6
# 11  2021     12       101832.0
# 12  2022      9        67054.0
# 13  2022     10        57034.0
# 14  2022     11        77410.2
# 15  2022     12        63890.6
# 16  2023      1        56549.8
# 17  2023      2        58240.2
# 18  2023      3        52630.2
# 19  2023      4        35031.8
# 20  2023      5        40758.0
# 21  2023      6        59194.4
# 22  2023      7        27424.2
# 23  2023      8        52895.8

# %%
import matplotlib.pyplot as plt
from datetime import date
for i in range (0,24):
  monthly_total_df.loc[i,'day']=date(monthly_total_df.loc[i,'year'],monthly_total_df.loc[i,'month'],1)

fig, ax = plt.subplots(figsize=(10,10))
ax.plot(monthly_total_df['day'],monthly_total_df['monthly_total'])
ax.set_xlabel('date')
ax.set_title('monthly_total')
plt.grid(True)
plt.show()

# %%
#Yearly anaysis
Monthly_average_consumption = monthly_total_df.groupby(['year'])['monthly_total'].mean()

# %%
Monthly_average_consumption
# Out:
# year
# 2021    115989.766667
# 2022     66347.200000
# 2023     47840.550000
# Name: monthly_total, dtype: float64

# %%
mean_daily_consumption = daily_sum_df['total of the day'].mean()
print(mean_daily_consumption)
# Out:
# 2798.340740740741

# %%
mean_monthly_consumption=monthly_total_df['monthly_total'].mean()
print(mean_monthly_consumption)
# Out:
# 84999.59999999999

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
def make_graph(df_2022,df_2021,name):
  with PdfPages(f'{name}') as pdf:
      a=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
      for i in range (1,13):
        fig, axs = plt.subplots(2, 4, figsize=(15, 10))
        for j in range (0,7):
          df_temp2 = df_2022[(df_2022['month'] == i) & (df_2022['day'] == a[j])]
          df_temp2 = df_temp2.reset_index(drop=True)
          x_labels=df_temp2['hour'][0:24]
          y_labels5=df_temp2['values'][0:24]
          y_labels6=df_temp2['values'][24:48]
          y_labels7=df_temp2['values'][48:72]
          y_labels8=df_temp2['values'][72:96]
          df_temp1 = df_2021[(df_2021['month'] == i) & (df_2021['day'] == a[j])]
          df_temp1 = df_temp1.reset_index(drop=True)
          y_labels1=df_temp1['values'][0:24]
          y_labels2=df_temp1['values'][24:48]
          y_labels3=df_temp1['values'][48:72]
          y_labels4=df_temp1['values'][72:96]
          plt.plot(x_labels,y_labels1,label=f"{df_temp1.loc[0,'date']} 2021")
          plt.plot(x_labels,y_labels2,label=f"{df_temp1.loc[24,'date']} 2021")
          plt.plot(x_labels,y_labels3,label=f"{df_temp1.loc[48,'date']} 2021")
          plt.plot(x_labels,y_labels4,label=f"{df_temp1.loc[72,'date']} 2021")
          plt.plot(x_labels,y_labels5,label=f"{df_temp2.loc[0,'date']} 2022")
          plt.plot(x_labels,y_labels6,label=f"{df_temp2.loc[24,'date']} 2022")
          plt.plot(x_labels,y_labels7,label=f"{df_temp2.loc[48,'date']} 2022")
          plt.plot(x_labels,y_labels8,label=f"{df_temp2.loc[72,'date']} 2022")
          plt.xlabel('hours')
          plt.ylabel('values')
          plt.title(f"Day: {a[j]}, Month :{df_temp1.loc[0,'month']} ")
          plt.legend(loc='upper right',fontsize='small')
          plt.subplot(2, 4, (j+1))
        plt.tight_layout()
        pdf.savefig()
        plt.plot()
        plt.show()
        plt.close()

# %%
def allote_2021(df_2021):
    df_2021['day'] = ''
    a = ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday']
    for i in range(0, 365):
        for j in range(0, 24):
            df_2021.loc[((24 * i) + j), 'day'] = a[i % 7]
    return df_2021

# %%
def allote_2022(df_2022):
    df_2022['day'] = ''
    a = ['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
    for i in range(0, 365):
        for j in range(0, 24):
            df_2022.loc[((24 * i) + j), 'day'] = a[i % 7]
    return df_2022

# %%
df_2021=pd.read_csv('VA_2021.csv')
df_2022=pd.read_csv('VA_2022.csv')
df_2021=allote_2021(df_2021)
df_2022=allote_2022(df_2022)
make_graph(df_2022,df_2021,'VA.pdf')
