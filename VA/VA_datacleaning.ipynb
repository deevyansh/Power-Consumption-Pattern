# %%
# Importing the important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing the documents
df1=pd.read_excel('VAl1Sep22-1Sep23.xlsx')
df1=df1.drop_duplicates()
df2=pd.read_csv('VAl20_21.csv')
df2=df2.drop_duplicates()

# %%
#Changing the columns and rows of the df2
df2[['Date','values','measurement']]=df2['Date;value;measurement'].str.split(';',expand=True)
df2=df2.drop(columns='Date;value;measurement')
df2[['date','time']]=df2['Date'].str.split(' ',expand=True)
df2=df2.drop(columns='Date')
df2[['dates','month','year']]=df2['date'].str.split('-',expand=True)
df2=df2.drop(columns='date')
df2[['hour','minutes']]=df2['time'].str.split(':',expand=True)
df2=df2.drop(columns='time')
df2['minutes'].value_counts()
df2=df2.drop(columns='minutes')
df2=df2.rename(columns={'dates':'date'})
df2=df2.drop(columns='measurement')
df2['year'] = df2['year'].astype(int)
df2['month'] = df2['month'].astype(int)
df2['date'] = df2['date'].astype(int)
df2['hour'] = df2['hour'].astype(int)
df2
# Out:
#      values  date  month  year  hour
# 0       5.6    31     12  2020     1
# 1       4.8    31     12  2020     2
# 2       5.6    31     12  2020     3
# 3       7.2    31     12  2020     4
# 4       4.8    31     12  2020     5
# ...     ...   ...    ...   ...   ...
# 8779   10.4    31     12  2021    20
# 8780   10.4    31     12  2021    21
# 8781     10    31     12  2021    22
# 8782    8.8    31     12  2021    23
# 8783    8.4     1      1  2022     0
#
# [8784 rows x 5 columns]

# %%
#changing the columns and rows of df1
df1['date']=df1['dt'].dt.day
df1['month']=df1['dt'].dt.month
df1['year']=df1['dt'].dt.year
df1['hour']=df1['dt'].dt.hour
df1=df1.drop(columns='dt')
df1
# Out:
#       values  date  month  year  hour
# 0       59.4     1      9  2022     0
# 1      148.4     1      9  2022     1
# 2      176.4     1      9  2022     2
# 3      171.6     1      9  2022     3
# 4      177.4     1      9  2022     4
# ...      ...   ...    ...   ...   ...
# 8730   169.4    31      8  2023    19
# 8731   171.2    31      8  2023    20
# 8732   168.6    31      8  2023    21
# 8733   153.8    31      8  2023    22
# 8734   154.2    31      8  2023    23
#
# [8735 rows x 5 columns]

# %%
df1 = df1.drop_duplicates()
row_data = {
    'hour': 3,
    'date': 28,
    'month': 3,'year' : 2023, 'values': df1[(df1['hour'] == 2) & (df1['date'] == 28) & (df1['month'] == 3)].iloc[0]['values']
}
df1['date']=df1['date'].astype(int)
df1['month']=df1['month'].astype(int)
df1['hour']=df1['hour'].astype(int)
df1.loc[8735]=(row_data)
df1 = df1.sort_values(by=['month', 'date', 'hour'])
df1 = df1.reset_index(drop=True)
df1
# Out:
#       values  date  month  year  hour
# 0        5.6     1      1  2023     0
# 1        3.2     1      1  2023     1
# 2        3.2     1      1  2023     2
# 3        5.2     1      1  2023     3
# 4       10.8     1      1  2023     4
# ...      ...   ...    ...   ...   ...
# 8731     6.4    31     12  2022    19
# 8732     4.4    31     12  2022    20
# 8733     4.8    31     12  2022    21
# 8734     4.4    31     12  2022    22
# 8735     6.2    31     12  2022    23
#
# [8736 rows x 5 columns]

# %%
df1['year'].value_counts()
# Out:
# year
# 2023    5832
# 2022    2904
# Name: count, dtype: int64

# %%
df2
# Out:
#      values  date  month  year  hour
# 0       5.6    31     12  2020     1
# 1       4.8    31     12  2020     2
# 2       5.6    31     12  2020     3
# 3       7.2    31     12  2020     4
# 4       4.8    31     12  2020     5
# ...     ...   ...    ...   ...   ...
# 8779   10.4    31     12  2021    20
# 8780   10.4    31     12  2021    21
# 8781     10    31     12  2021    22
# 8782    8.8    31     12  2021    23
# 8783    8.4     1      1  2022     0
#
# [8784 rows x 5 columns]

# %%
# df2[df2['month']==12]['date'].value_counts()
# df2[df2['month']==3][df2['date']==28]['hour'].value_counts() # hour =3 missing
# df2[df2['month']==10][df2['date']==31]['hour'].value_counts() # hour= 3 is more
# df2[df2['hour']==23]['month'].value_counts()
df2['hour']=df2['hour'].astype(int)
df2['month']=df2['month'].astype(int)
df2['year']=df2['year'].astype(int)
df2.loc[len(df2),'hour']=3
df2.loc[len(df2)-1,'month']=3
df2.loc[len(df2)-1,'date']=28
df2.loc[len(df2)-1,'year']=2020
df2.loc[len(df2)-1,'values']=(df2[(df2['hour']==3) & (df2['month']==10)& (df2['date']==31)].iloc[0])['values']

# %%
(df2[(df2['hour']==3) & (df2['month']==10)& (df2['date']==31)]).index[0]
# Out:
# 7297

# %%
df2
# Out:
#      values  date  month    year  hour
# 0       5.6  31.0   12.0  2020.0   1.0
# 1       4.8  31.0   12.0  2020.0   2.0
# 2       5.6  31.0   12.0  2020.0   3.0
# 3       7.2  31.0   12.0  2020.0   4.0
# 4       4.8  31.0   12.0  2020.0   5.0
# ...     ...   ...    ...     ...   ...
# 8780   10.4  31.0   12.0  2021.0  21.0
# 8781     10  31.0   12.0  2021.0  22.0
# 8782    8.8  31.0   12.0  2021.0  23.0
# 8783    8.4   1.0    1.0  2022.0   0.0
# 8784      8  28.0    3.0  2020.0   3.0
#
# [8785 rows x 5 columns]

# %%
df2.drop(7297)
# Out:
#      values  date  month    year  hour
# 0       5.6  31.0   12.0  2020.0   1.0
# 1       4.8  31.0   12.0  2020.0   2.0
# 2       5.6  31.0   12.0  2020.0   3.0
# 3       7.2  31.0   12.0  2020.0   4.0
# 4       4.8  31.0   12.0  2020.0   5.0
# ...     ...   ...    ...     ...   ...
# 8780   10.4  31.0   12.0  2021.0  21.0
# 8781     10  31.0   12.0  2021.0  22.0
# 8782    8.8  31.0   12.0  2021.0  23.0
# 8783    8.4   1.0    1.0  2022.0   0.0
# 8784      8  28.0    3.0  2020.0   3.0
#
# [8784 rows x 5 columns]

# %%
# Sort the DataFrame by the desired columns
df2 = df2.sort_values(by=['year', 'month', 'date','hour'])

# Reset the index and drop the old index
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#      values  date  month    year  hour
# 0         8  28.0    3.0  2020.0   3.0
# 1       5.6  31.0   12.0  2020.0   1.0
# 2       4.8  31.0   12.0  2020.0   2.0
# 3       5.6  31.0   12.0  2020.0   3.0
# 4       7.2  31.0   12.0  2020.0   4.0
# ...     ...   ...    ...     ...   ...
# 8780   10.4  31.0   12.0  2021.0  20.0
# 8781   10.4  31.0   12.0  2021.0  21.0
# 8782     10  31.0   12.0  2021.0  22.0
# 8783    8.8  31.0   12.0  2021.0  23.0
# 8784    8.4   1.0    1.0  2022.0   0.0
#
# [8785 rows x 5 columns]

# %%
df2.drop(df2.head(24).index,inplace=True)
df2.drop(df2.tail(1).index,inplace=True)
df2=df2.reset_index()

# %%
df1=df1.sort_values(by=['month','date','hour'])

# %%
df2
# Out:
#       index values  date  month    year  hour
# 0        24    5.6   1.0    1.0  2021.0   0.0
# 1        25    5.6   1.0    1.0  2021.0   1.0
# 2        26    5.6   1.0    1.0  2021.0   2.0
# 3        27    5.2   1.0    1.0  2021.0   3.0
# 4        28      6   1.0    1.0  2021.0   4.0
# ...     ...    ...   ...    ...     ...   ...
# 8755   8779   10.8  31.0   12.0  2021.0  19.0
# 8756   8780   10.4  31.0   12.0  2021.0  20.0
# 8757   8781   10.4  31.0   12.0  2021.0  21.0
# 8758   8782     10  31.0   12.0  2021.0  22.0
# 8759   8783    8.8  31.0   12.0  2021.0  23.0
#
# [8760 rows x 6 columns]

# %%
df1
# Out:
#       values  date  month  year  hour
# 0        5.6     1      1  2023     0
# 1        3.2     1      1  2023     1
# 2        3.2     1      1  2023     2
# 3        5.2     1      1  2023     3
# 4       10.8     1      1  2023     4
# ...      ...   ...    ...   ...   ...
# 8731     6.4    31     12  2022    19
# 8732     4.4    31     12  2022    20
# 8733     4.8    31     12  2022    21
# 8734     4.4    31     12  2022    22
# 8735     6.2    31     12  2022    23
#
# [8736 rows x 5 columns]

# %%
# Exporting the files
df1.to_csv('VA_file1.csv')
df2.to_csv('VA_file2.csv')
